# %%
import pandas as pd
import numpy as np 
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
globalTemp = pd.read_csv('/Users/thomashinman/Desktop/Final Project data Sets Tom Hinman/Global Land Temperature/GlobalTemperatures.csv')
globalTemp.head
# Out:
# <bound method NDFrame.head of               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
globalTemp.LandAndOceanAverageTemperature.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
globalTemp.plot.scatter(x="dt", y= "LandAndOceanAverageTemperature")
# Out:
# <AxesSubplot:xlabel='dt', ylabel='LandAndOceanAverageTemperature'>

# %%
globalTemp.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
globalTemp.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# ...

# %%
globalTemp.columns
# Out:
# Index(['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'LandMaxTemperature', 'LandMaxTemperatureUncertainty',
#        'LandMinTemperature', 'LandMinTemperatureUncertainty',
#        'LandAndOceanAverageTemperature',
#        'LandAndOceanAverageTemperatureUncertainty'],
#       dtype='object')

# %%
globalTemp.LandAverageTemperature.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        3.034
# 1        3.083
# 2        5.626
# 3        8.490
# 4       11.573
#          ...
# 3187    14.755
# 3188    12.999
# 3189    10.801
# 3190     7.433
# 3191     5.518
# Name: LandAverageTemperature, Length: 3192, dtype: float64>

# %%
globalTemp.LandAverageTemperature.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0        3.034
# 1        3.083
# 2        5.626
# 3        8.490
# 4       11.573
#          ...
# 3187    14.755
# 3188    12.999
# 3189    10.801
# 3190     7.433
# 3191     5.518
# Name: LandAverageTemperature, Length: 3192, dtype: float64>

# %%
globalTemp.plot.scatter(x="dt", y= "LandAverageTemperature")
# Out:
# <AxesSubplot:xlabel='dt', ylabel='LandAverageTemperature'>

# %%
globalTemp.hist('LandAverageTemperature')
# Out:
# array([[<AxesSubplot:title={'center':'LandAverageTemperature'}>]],
#       dtype=object)

# %%
globalTemp.plot.scatter(x="dt", y= "LandMaxTemperature")
# Out:
# <AxesSubplot:xlabel='dt', ylabel='LandMaxTemperature'>

# %%
globalTemp.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200  1850-01-01                   0.749                              1.105
# 1201  1850-02-01                   3.071                              1.275
# 1202  1850-03-01                   4.954                              0.955
# 1203  1850-04-01                   7.217                              0.665
# 1204  1850-05-01                  10.004                              0.617
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
globalTemp.plot.scatter(x="dt", y= "LandMaxTemperature")
# Out:
# <AxesSubplot:xlabel='dt', ylabel='LandMaxTemperature'>

# %%
 globalTemp.hist('LandAverageTemperature')
# Out:
# array([[<AxesSubplot:title={'center':'LandAverageTemperature'}>]],
#       dtype=object)

# %%
globalTemp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
atlanticCyclone= pd.read_csv('/Users/thomashinman/Desktop/Final Project data Sets Tom Hinman/hurandtyp/atlantic.csv')

# %%
atlanticCyclone.head
# Out:
# <bound method NDFrame.head of              ID                 Name      Date  Time Event Status Latitude  \
# 0      AL011851              UNNAMED  18510625     0           HU    28.0N
# 1      AL011851              UNNAMED  18510625   600           HU    28.0N
# 2      AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3      AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4      AL011851              UNNAMED  18510625  2100     L     HU    28.2N
# ...         ...                  ...       ...   ...   ...    ...      ...
# 49100  AL122015                 KATE  20151112  1200           EX    41.3N
# 49101  AL122015                 KATE  20151112  1800           EX    41.9N
# 49102  AL122015                 KATE  20151113     0           EX    41.5N
# 49103  AL122015                 KATE  20151113   600           EX    40.8N
# 49104  AL122015                 KATE  20151113  1200           EX    40.7N
#
# ...

# %%
pacificCyclone = pd.read_csv('/Users/thomashinman/Desktop/Final Project data Sets Tom Hinman/hurandtyp/pacific.csv')

# %%
pacificCyclone.head
# Out:
# <bound method NDFrame.head of              ID                 Name      Date  Time Event Status Latitude  \
# 0      EP011949              UNNAMED  19490611     0           TS    20.2N
# 1      EP011949              UNNAMED  19490611   600           TS    20.2N
# 2      EP011949              UNNAMED  19490611  1200           TS    20.2N
# 3      EP011949              UNNAMED  19490611  1800           TS    20.3N
# 4      EP011949              UNNAMED  19490612     0           TS    20.4N
# ...         ...                  ...       ...   ...   ...    ...      ...
# 26132  EP222015               SANDRA  20151128  1200           LO    21.7N
# 26133  EP222015               SANDRA  20151128  1800           LO    22.4N
# 26134  EP222015               SANDRA  20151129     0           LO    23.1N
# 26135  EP222015               SANDRA  20151129   600           LO    23.5N
# 26136  EP222015               SANDRA  20151129  1200           LO    24.2N
#
# ...

# %%
AtlPac = pd.merge(pacificCyclone,atlanticCyclone,on='Date')

# %%
AtlPac.head
# Out:
# <bound method NDFrame.head of            ID_x               Name_x      Date  Time_x Event_x Status_x  \
# 0      EP031949              UNNAMED  19490903    1200               TS
# 1      EP031949              UNNAMED  19490903    1200               TS
# 2      EP031949              UNNAMED  19490903    1200               TS
# 3      EP031949              UNNAMED  19490903    1200               TS
# 4      EP031949              UNNAMED  19490903    1200               TS
# ...         ...                  ...       ...     ...     ...      ...
# 63960  EP182015                 NORA  20151015    1800               LO
# 63961  EP192015                 OLAF  20151015       0               TD
# 63962  EP192015                 OLAF  20151015     600               TD
# 63963  EP192015                 OLAF  20151015    1200               TD
# 63964  EP192015                 OLAF  20151015    1800               TD
#
#       Latitude_x Longitude_x  Maximum Wind_x  Minimum Pressure_x  ...  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-a5c298ffc615> in <module>
# ...

# %%
AtlPac.plot.hist("Maximum_Wind")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-1530521f178a> in <module>
# ----> 1 GlobalAtlPac= pd.merge(globalTemp, AtlPac, left_on('dt'), rihght_on('Date'))
#       2
#
# NameError: name 'left_on' is not defined

# %%
AtlPac.hist('Date')
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>]], dtype=object)

# %%
AtlPac.columns
# Out:
# Index(['ID_x', 'Name_x', 'Date', 'Time_x', 'Event_x', 'Status_x', 'Latitude_x',
#        'Longitude_x', 'Maximum Wind_x', 'Minimum Pressure_x', 'Low Wind NE_x',
#        'Low Wind SE_x', 'Low Wind SW_x', 'Low Wind NW_x', 'Moderate Wind NE_x',
#        'Moderate Wind SE_x', 'Moderate Wind SW_x', 'Moderate Wind NW_x',
#        'High Wind NE_x', 'High Wind SE_x', 'High Wind SW_x', 'High Wind NW_x',
#        'ID_y', 'Name_y', 'Time_y', 'Event_y', 'Status_y', 'Latitude_y',
#        'Longitude_y', 'Maximum Wind_y', 'Minimum Pressure_y', 'Low Wind NE_y',
#        'Low Wind SE_y', 'Low Wind SW_y', 'Low Wind NW_y', 'Moderate Wind NE_y',
#        'Moderate Wind SE_y', 'Moderate Wind SW_y', 'Moderate Wind NW_y',
#        'High Wind NE_y', 'High Wind SE_y', 'High Wind SW_y', 'High Wind NW_y'],
#       dtype='object')

# %%
AtlPac.plot.scatter(y='Maximum Wind_x', x=('Date'))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Maximum Wind_x'>

# %%
sns.distplot(AtlPac['Maximum Wind_x'])
# Out:
# /Users/thomashinman/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Maximum Wind_x', ylabel='Density'>

# %%
atlanticCyclone.plot.scatter(y='Maximum Wind', x=('Date'))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Maximum Wind'>

# %%
pacificCyclone.plot.scatter(y='Maximum Wind', x=('Date'))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Maximum Wind'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-96-75959cc0ba88> in <module>
# ----> 1 seaLevel = pd.read_csv('/Users/thomashinman/Desktop/Final Project data Sets Tom Hinman/global_sealevel.csv')
#
# ...

# %%
atlanticCyclone.plot.scatter(x="Date", y= "Minimum Pressure")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Minimum Pressure'>

# %%
atlanticCyclone['Minimum Pressure'].replace([-999], 0)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 49100    981
# 49101    983
# 49102    985
# 49103    985
# 49104    987
# Name: Minimum Pressure, Length: 49105, dtype: int64

# %%
atlanticCyclone.plot.scatter(x="Date", y= "Minimum Pressure")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Minimum Pressure'>

# %%
pacificCyclone['Minimum Pressure'].replace([-999], 0)
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 26132    1002
# 26133    1007
# 26134    1008
# 26135    1009
# 26136    1010
# Name: Minimum Pressure, Length: 26137, dtype: int64

# %%
pacificCyclone.plot.scatter(x="Date", y= "Minimum Pressure")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Minimum Pressure'>

# %%
seaLevel = pd.read_csv('/Users/thomashinman/Desktop/Global Average Sea Level 92-21 2.csv')

# %%
seaLevel.head
# Out:
# <bound method NDFrame.head of             Date  TOPEX/Poseidon  Jason-1  Jason-2  Jason-3
# 0     1905-06-14          -16.04      NaN      NaN      NaN
# 1     1905-06-14          -17.74      NaN      NaN      NaN
# 2     1905-06-15          -14.64      NaN      NaN      NaN
# 3     1905-06-15          -19.64      NaN      NaN      NaN
# 4     1905-06-15          -25.04      NaN      NaN      NaN
# ...          ...             ...      ...      ...      ...
# 1293  1905-07-13             NaN      NaN      NaN     80.3
# 1294  1905-07-13             NaN      NaN      NaN     79.6
# 1295  1905-07-13             NaN      NaN      NaN     79.8
# 1296  1905-07-13             NaN      NaN      NaN     80.9
# 1297  1905-07-13             NaN      NaN      NaN     77.3
#
# [1298 rows x 5 columns]>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Topex/Poseidon'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-d9bb6a5b71f5> in <module>
# ...
